# %% [markdown]
# # Editing collected data from Twitter
#
# The proper parsing of the info extracted from Twitter will be done and some tests with the input will be done.

# %%
# Libraries
import json

# %%
# Opening the file with the extracted data
with open("collected_tweets_2021-09-26-10-29-12.txt", "r") as file:
    tweets = file.readlines()

# %%
tweets[0]
# Out:
# '"{\\"created_at\\":\\"Sun Sep 26 13:29:17 +0000 2021\\",\\"id\\":1442119084070424582,\\"id_str\\":\\"1442119084070424582\\",\\"text\\":\\"#FreezePaymentsToJunta \\\\n#WhatsHappeningInMyanmar #Sep26Coup https:\\\\/\\\\/t.co\\\\/ZylbczSKXe\\",\\"source\\":\\"\\\\u003ca href=\\\\\\"http:\\\\/\\\\/twitter.com\\\\/download\\\\/iphone\\\\\\" rel=\\\\\\"nofollow\\\\\\"\\\\u003eTwitter for iPhone\\\\u003c\\\\/a\\\\u003e\\",\\"truncated\\":false,\\"in_reply_to_status_id\\":null,\\"in_reply_to_status_id_str\\":null,\\"in_reply_to_user_id\\":null,\\"in_reply_to_user_id_str\\":null,\\"in_reply_to_screen_name\\":null,\\"user\\":{\\"id\\":983942710368153600,\\"id_str\\":\\"983942710368153600\\",\\"name\\":\\"Thet Htar\\",\\"screen_name\\":\\"TwEETsOfHtar\\",\\"location\\":null,\\"url\\":null,\\"description\\":\\"Revolution must be prevailed. Dictatorship must be root-off.\\",\\"translator_type\\":\\"none\\",\\"protected\\":false,\\"verified\\":false,\\"followers_count\\":42,\\"friends_count\\":118,\\"listed_count\\":0,\\"favourites_count\\":6412,\\"statuses_count\\":9252,\\"created_at\\":\\"Wed Apr 11 05:39:57 +0000 2018\\",\\"utc_offset\\":null,\\"time_zone\\":null,\\"geo_enabled\\":false,\\"lang\\":null,\\"contributors_enabled\\":false,\\"is_translator\\":false,\\"profile_background_color\\":\\"F5F8FA\\",\\"profile_background_image_url\\":\\"\\",\\"profile_background_image_url_https\\":\\"\\",\\"profile_background_tile\\":false,\\"profile_link_color\\":\\"1DA1F2\\",\\"profile_sidebar_border_color\\":\\"C0DEED\\",\\"profile_sidebar_fill_color\\":\\"DDEEF6\\",\\"profile_text_color\\":\\"333333\\",\\"profile_use_background_image\\":true,\\"profile_image_url\\":\\"http:\\\\/\\\\/pbs.twimg.com\\\\/profile_images\\\\/1402615312814469121\\\\/K03Y_kzG_normal.jpg\\",\\"profile_image_url_https\\":\\"https:\\\\/\\\\/pbs.twimg.com\\\\/profile_images\\\\/1402615312814469121\\\\/K03Y_kzG_normal.jpg\\",\\"profile_banner_url\\":\\"https:\\\\/\\\\/pbs.twimg.com\\\\/profile_banners\\\\/983942710368153600\\\\/1615730058\\",\\"default_profile\\":true,\\"default_profile_image\\":false,\\"following\\":null,\\"follow_request_sent\\":null,\\"notifications\\":null,\\"withheld_in_countries\\":[]},\\"geo\\":null,\\"coordinates\\":null,\\"place\\":null,\\"contributors\\":null,\\"quoted_status_id\\":1441970576365477896,\\"quoted_status_id_str\\":\\"1441970576365477896\\",\\"quoted_status\\":{\\"created_at\\":\\"Sun Sep 26 03:39:10 +0000 2021\\",\\"id\\":1441970576365477896,\\"id_str\\":\\"1441970576365477896\\",\\"text\\":\\"#ADB warns about lower #GDP growth due to #COVID-19 as Myanmar sees drop | Mizzima #Myanmar News and Insight\\\\u2026 https:\\\\/\\\\/t.co\\\\/YYwnkWESl0\\",\\"display_text_range\\":[0,140],\\"source\\":\\"\\\\u003ca href=\\\\\\"https:\\\\/\\\\/mobile.twitter.com\\\\\\" rel=\\\\\\"nofollow\\\\\\"\\\\u003eTwitter Web App\\\\u003c\\\\/a\\\\u003e\\",\\"truncated\\":true,\\"in_reply_to_status_id\\":null,\\"in_reply_to_status_id_str\\":null,\\"in_reply_to_user_id\\":null,\\"in_reply_to_user_id_str\\":null,\\"in_reply_to_screen_name\\":null,\\"user\\":{\\"id\\":76294023,\\"id_str\\":\\"76294023\\",\\"name\\":\\"Mizzima News\\",\\"screen_name\\":\\"MizzimaNews\\",\\"location\\":\\"Myanmar\\",\\"url\\":\\"http:\\\\/\\\\/www.mizzima.com\\",\\"description\\":\\"Myanmar News brings you the latest news and insight into Burma or Myanmar as the country transitions. http:\\\\/\\\\/t.me\\\\/mizzimatv\\",\\"translator_type\\":\\"none\\",\\"protected\\":false,\\"verified\\":true,\\"followers_count\\":682947,\\"friends_count\\":867,\\"listed_count\\":965,\\"favourites_count\\":10,\\"statuses_count\\":26360,\\"created_at\\":\\"Tue Sep 22 09:46:02 +0000 2009\\",\\"utc_offset\\":null,\\"time_zone\\":null,\\"geo_enabled\\":true,\\"lang\\":null,\\"contributors_enabled\\":false,\\"is_translator\\":false,\\"profile_background_color\\":\\"3D1F22\\",\\"profile_background_image_url\\":\\"http:\\\\/\\\\/abs.twimg.com\\\\/images\\\\/themes\\\\/theme14\\\\/bg.gif\\",\\"profile ...

# %%
# Checking the tweet content and class and parsing it to a more 'structured' format
print(type(tweets[0]))
print(json.loads(tweets[0])) # Parses the content to a 'structured' string
print(type(json.loads(tweets[0])))
# Out:
# <class 'str'>
# {"created_at":"Sun Sep 26 13:29:17 +0000 2021","id":1442119084070424582,"id_str":"1442119084070424582","text":"#FreezePaymentsToJunta \n#WhatsHappeningInMyanmar #Sep26Coup https:\/\/t.co\/ZylbczSKXe","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":983942710368153600,"id_str":"983942710368153600","name":"Thet Htar","screen_name":"TwEETsOfHtar","location":null,"url":null,"description":"Revolution must be prevailed. Dictatorship must be root-off.","translator_type":"none","protected":false,"verified":false,"followers_count":42,"friends_count":118,"listed_count":0,"favourites_count":6412,"statuses_count":9252,"created_at":"Wed Apr 11 05:39:57 +0000 2018","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1402615312814469121\/K03Y_kzG_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1402615312814469121\/K03Y_kzG_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/983942710368153600\/1615730058","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null,"withheld_in_countries":[]},"geo":null,"coordinates":null,"place":null,"contributors":null,"quoted_status_id":1441970576365477896,"quoted_status_id_str":"1441970576365477896","quoted_status":{"created_at":"Sun Sep 26 03:39:10 +0000 2021","id":1441970576365477896,"id_str":"1441970576365477896","text":"#ADB warns about lower #GDP growth due to #COVID-19 as Myanmar sees drop | Mizzima #Myanmar News and Insight\u2026 https:\/\/t.co\/YYwnkWESl0","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":76294023,"id_str":"76294023","name":"Mizzima News","screen_name":"MizzimaNews","location":"Myanmar","url":"http:\/\/www.mizzima.com","description":"Myanmar News brings you the latest news and insight into Burma or Myanmar as the country transitions. http:\/\/t.me\/mizzimatv","translator_type":"none","protected":false,"verified":true,"followers_count":682947,"friends_count":867,"listed_count":965,"favourites_count":10,"statuses_count":26360,"created_at":"Tue Sep 22 09:46:02 +0000 2009","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"3D1F22","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme14\/bg.gif","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme14\/bg.gif","profile_background_tile":false,"profile_link_color":"DD2E44","profile_sidebar_border_color":"FFDF0F","profile_sidebar_fill_color":"ECF00C","profile_text_color":"00479E","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/731071726612668417\/ZgYfIpq2_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/731071726612668417\/ZgYfIpq2_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/76294023\/1614432757","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null,"withhel ...
#
# <class 'str'>

# %%
# Parsing the structured string to a dictionary
json.loads(json.loads(tweets[0]))
# Out:
# {'created_at': 'Sun Sep 26 13:29:17 +0000 2021',
#  'id': 1442119084070424582,
#  'id_str': '1442119084070424582',
#  'text': '#FreezePaymentsToJunta \n#WhatsHappeningInMyanmar #Sep26Coup https://t.co/ZylbczSKXe',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 983942710368153600,
#   'id_str': '983942710368153600',
#   'name': 'Thet Htar',
#   'screen_name': 'TwEETsOfHtar',
#   'location': None,
#   'url': None,
#   'description': 'Revolution must be prevailed. Dictatorship must be root-off.',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 42,
#   'friends_count': 118,
#   'listed_count': 0,
#   'favourites_count': 6412,
#   'statuses_count': 9252,
#   'created_at': 'Wed Apr 11 05:39:57 +0000 2018',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1402615312814469121/K03Y_kzG_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1402615312814469121/K03Y_kzG_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/983942710368153600/1615730058',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'quoted_status_id': 1441970576365477896,
#  'quoted_status_id_str': '1441970576365477896',
#  'quoted_status': {'created_at': 'Sun Sep 26 03:39:10 +0000 2021',
#   'id': 1441970576365477896,
#   'id_str': '1441970576365477896',
#   'text': '#ADB warns about lower #GDP growth due to #COVID-19 as Myanmar sees drop | Mizzima #Myanmar News and Insight… https://t.co/YYwnkWESl0',
#   'display_text_range': [0, 140],
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 76294023,
#    'id_str': '76294023',
#    'name': 'Mizzima News',
#    'screen_name': 'MizzimaNews',
#    'location': 'Myanmar',
#    'url': 'http://www.mizzima.com',
#    'description': 'Myanmar News brings you the latest news and insight into Burma or Myanmar as the country transitions. http://t.me/mizzimatv',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 682947,
#    'friends_count': 867,
#    'listed_count': 965,
#    'favourites_count': 10,
#    'statuses_count': 26360,
#    'created_at': 'Tue Sep 22 09:46:02 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '3D1F22',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': 'FFDF0F',
#    'profile_sidebar_fill_color': 'ECF00C',
#    'profile_text_color': '00479E',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/731071726612668417/ZgYfIpq2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/731071726612668417/ZgYfIpq2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/76294023/1614432757',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '#ADB warns about lower #GDP growth due to #COVID-19 as Myanmar sees drop | Mizzima #Myanmar News and Insight https://t.co/FHQNxpBHem\n-------------------------\nPlease support Mizzima Media sustainability by clicking the link to donate - https://t.co/trfff3WHYG https://t.co/TbKeBOOVCU',
#    'display_text_range': [0, 259],
#    'entities': {'hashtags': [{'text': 'ADB', 'indices': [0, 4]},
#      {'text': 'GDP', 'indices': [23, 27]},
#      {'text': 'COVID', 'indices': [42, 48]},
#      {'text': 'Myanmar', 'indices': [83, 91]}],
#     'urls': [{'url': 'https://t.co/FHQNxpBHem',
#       'expanded_url': 'https://bit.ly/3APeNE8',
#       'display_url': 'bit.ly/3APeNE8',
#       'indices': [109, 132]},
#      {'url': 'https://t.co/trfff3WHYG',
#       'expanded_url': 'https://bit.ly/2VhJ12U',
#       'display_url': 'bit.ly/2VhJ12U',
#       'indices': [236, 259]}],
#     'user_mentions': [],
#     'symbols': [],
#     'media': [{'id': 1441970525035642887,
#       'id_str': '1441970525035642887',
#       'indices': [260, 283],
#       'media_url': 'http://pbs.twimg.com/media/FALojXlVQAc2IfF.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FALojXlVQAc2IfF.jpg',
#       'url': 'https://t.co/TbKeBOOVCU',
#       'display_url': 'pic.twitter.com/TbKeBOOVCU',
#       'expanded_url': 'https://twitter.com/MizzimaNews/status/1441970576365477896/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 800, 'h': 533, 'resize': 'fit'},
#        'medium': {'w': 800, 'h': 533, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1441970525035642887,
#       'id_str': '1441970525035642887',
#       'indices': [260, 283],
#       'media_url': 'http://pbs.twimg.com/media/FALojXlVQAc2IfF.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FALojXlVQAc2IfF.jpg',
#       'url': 'https://t.co/TbKeBOOVCU',
#       'display_url': 'pic.twitter.com/TbKeBOOVCU',
#       'expanded_url': 'https://twitter.com/MizzimaNews/status/1441970576365477896/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 800, 'h': 533, 'resize': 'fit'},
#        'medium': {'w': 800, 'h': 533, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]}},
#   'quote_count': 929,
#   'reply_count': 24,
#   'retweet_count': 211,
#   'favorite_count': 254,
#   'entities': {'hashtags': [{'text': 'ADB', 'indices': [0, 4]},
#     {'text': 'GDP', 'indices': [23, 27]},
#     {'text': 'COVID', 'indices': [42, 48]},
#     {'text': 'Myanmar', 'indices': [83, 91]}],
#    'urls': [{'url': 'https://t.co/YYwnkWESl0',
#      'expanded_url': 'https://twitter.com/i/web/status/1441970576365477896',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [110, 133]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/ZylbczSKXe',
#   'expanded': 'https://twitter.com/MizzimaNews/status/1441970576365477896',
#   'display': 'twitter.com/MizzimaNews/st…'},
#  'is_quote_status': True,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [{'text': 'FreezePaymentsToJunta',
#     'indices': [0, 22]},
#    {'text': 'WhatsHappeningInMyanmar', 'indices': [24, 48]},
#    {'text': 'Sep26Coup', 'indices': [49, 59]}],
#   'urls': [{'url': 'https://t.co/ZylbczSKXe',
#     'expanded_url': 'https://twitter.com/MizzimaNews/status/1441970576365477896',
#     'display_url': 'twitter.com/MizzimaNews/st…',
#     'indices': [60, 83]}],
#   'user_mentions': [],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': True,
#  'filter_level': 'low',
#  'lang': 'und',
#  'timestamp_ms': '1632662957576'}

# %%
type(json.loads(json.loads(tweets[0])))
# Out:
# dict

# %%
# Parsing the tweet to a json (dict) format and exporting it to a file
with open("tweets.json", "w") as file2:
    json.dump( # Dumps the dict to a file
        json.loads( # Parses the string to a dict
            json.loads(tweets[0]) # Parses the content to a string
        ),
        file2
    )

# %% [markdown]
# ## Playing with the JSON

# %%
# Parsing all the collected tweets
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
len(parsed_tweets)
# Out:
# 106

# %%
# Checking upper level keys
tweet01 = parsed_tweets[0]
tweet01.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'])

# %%
# Accessing a key
tweet01["created_at"]
# Out:
# 'Sun Sep 26 13:29:17 +0000 2021'

# %%
# Cheking k:v as tuples
list(tweet01.items())[0]
# Out:
# ('created_at', 'Sun Sep 26 13:29:17 +0000 2021')

# %%
# Getting the tweet text
tweet01["text"]
# Out:
# '#FreezePaymentsToJunta \n#WhatsHappeningInMyanmar #Sep26Coup https://t.co/ZylbczSKXe'

# %%
# Getting lower level k:v
tweet01["user"]["id"]
# Out:
# 983942710368153600

# %%
# Deeper in the tree
tweet01["entities"]["hashtags"][0]["text"]
# Out:
# 'FreezePaymentsToJunta'

# %% [markdown]
# ## Transforming the tweets into a standard relational structure

# %%
# Libraries
import pandas as pd

# %%
test = pd.DataFrame(tweet01)
test
# Bad transformation (cross the attrs)
# Out:
#                                    created_at                   id  \
# id             Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# id_str         Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# name           Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# screen_name    Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# location       Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# ...                                       ...                  ...
# display        Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# hashtags       Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# urls           Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# user_mentions  Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
# symbols        Sun Sep 26 13:29:17 +0000 2021  1442119084070424582
#
#                             id_str  \
# id             1442119084070424582
# id_str         1442119084070424582
# name           1442119084070424582
# screen_name    1442119084070424582
# location       1442119084070424582
# ...                            ...
# display        1442119084070424582
# hashtags       1442119084070424582
# urls           1442119084070424582
# user_mentions  1442119084070424582
# symbols        1442119084070424582
#
#                                                             text  \
# id             #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# id_str         #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# name           #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# screen_name    #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# location       #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# ...                                                          ...
# display        #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# hashtags       #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# urls           #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# user_mentions  #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
# symbols        #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
#
#                                                           source  truncated  \
# id             <a href="http://twitter.com/download/iphone" r...      False
# id_str         <a href="http://twitter.com/download/iphone" r...      False
# name           <a href="http://twitter.com/download/iphone" r...      False
# screen_name    <a href="http://twitter.com/download/iphone" r...      False
# location       <a href="http://twitter.com/download/iphone" r...      False
# ...                                                          ...        ...
# display        <a href="http://twitter.com/download/iphone" r...      False
# hashtags       <a href="http://twitter.com/download/iphone" r...      False
# urls           <a href="http://twitter.com/download/iphone" r...      False
# user_mentions  <a href="http://twitter.com/download/iphone" r...      False
# symbols        <a href="http://twitter.com/download/iphone" r...      False
#
#               in_reply_to_status_id in_reply_to_status_id_str  \
# id                             None                      None
# id_str                         None                      None
# name                           None                      None
# screen_name                    None                      None
# location                       None                      None
# ...                             ...                       ...
# display                        None                      None
# hashtags                       None                      None
# urls                           None                      None
# user_mentions                  None                      None
# symbols                        None                      None
#
#               in_reply_to_user_id in_reply_to_user_id_str  ... reply_count  \
# id                           None                    None  ...           0
# id_str                       None                    None  ...           0
# name                         None                    None  ...           0
# screen_name                  None                    None  ...           0
# location                     None                    None  ...           0
# ...                           ...                     ...  ...         ...
# display                      None                    None  ...           0
# hashtags                     None                    None  ...           0
# urls                         None                    None  ...           0
# user_mentions                None                    None  ...           0
# symbols                      None                    None  ...           0
#
#               retweet_count favorite_count  \
# id                        0              0
# id_str                    0              0
# name                      0              0
# screen_name               0              0
# location                  0              0
# ...                     ...            ...
# display                   0              0
# hashtags                  0              0
# urls                      0              0
# user_mentions             0              0
# symbols                   0              0
#
#                                                         entities favorited  \
# id                                                           NaN     False
# id_str                                                       NaN     False
# name                                                         NaN     False
# screen_name                                                  NaN     False
# location                                                     NaN     False
# ...                                                          ...       ...
# display                                                      NaN     False
# hashtags       [{'text': 'FreezePaymentsToJunta', 'indices': ...     False
# urls           [{'url': 'https://t.co/ZylbczSKXe', 'expanded_...     False
# user_mentions                                                 []     False
# symbols                                                       []     False
#
#               retweeted  possibly_sensitive filter_level lang   timestamp_ms
# id                False                True          low  und  1632662957576
# id_str            False                True          low  und  1632662957576
# name              False                True          low  und  1632662957576
# screen_name       False                True          low  und  1632662957576
# location          False                True          low  und  1632662957576
# ...                 ...                 ...          ...  ...            ...
# display           False                True          low  und  1632662957576
# hashtags          False                True          low  und  1632662957576
# urls              False                True          low  und  1632662957576
# user_mentions     False                True          low  und  1632662957576
# symbols           False                True          low  und  1632662957576
#
# [71 rows x 32 columns]

# %%
df = pd.DataFrame(tweet01).reset_index(drop=True).iloc[:1]
df
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Sep 26 13:29:17 +0000 2021  1442119084070424582  1442119084070424582
#
#                                                 text  \
# 0  #FreezePaymentsToJunta \n#WhatsHappeningInMyan...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... reply_count retweet_count favorite_count  \
# 0                    None  ...           0             0              0
#
#   entities favorited retweeted  possibly_sensitive filter_level lang  \
# 0      NaN     False     False                True          low  und
#
#     timestamp_ms
# 0  1632662957576
#
# [1 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status', 'quoted_status_permalink', 'is_quote_status',
#        'quote_count', 'reply_count', 'retweet_count', 'favorite_count',
#        'entities', 'favorited', 'retweeted', 'possibly_sensitive',
#        'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df.drop(columns=['quote_count',
                 'reply_count',
                 'retweet_count', 
                 'favorite_count',
                 'favorited', 
                 'retweeted',
                 'user',
                 'entities'],
        inplace=True) # inplace=True persists the modification in the df
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status', 'quoted_status_permalink', 'is_quote_status',
#        'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')
